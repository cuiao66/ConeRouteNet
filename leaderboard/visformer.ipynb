# %%
import timm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_228639/609002727.py in <module>
# ----> 1 import timm
#
# ModuleNotFoundError: No module named 'timm'

# %%
timm.list_models('*former*')
# Out:
# ['visformer_small', 'visformer_tiny']

# %%
net = timm.create_model('visformer_small', pretrained=False)

# %%
net = timm.create_model('resnet14d', pretrained=True)
# Out:
# Visformer(
#   (stem): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (patch_embed1): PatchEmbed(
#     (proj): Conv2d(32, 192, kernel_size=(4, 4), stride=(4, 4))
#     (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (stage1): ModuleList(
#     (0): Block(
#       (drop_path): Identity()
#       (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (mlp): SpatialMlp(
#         (drop): Dropout(p=0.0, inplace=False)
#         (conv1): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (act1): GELU()
#         (conv2): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (act2): GELU()
# ...

# %%
import torch
from transformers import LongformerModel, LongformerConfig

# %%
longformerconfig = LongformerConfig()
longformer = LongformerModel(longformerconfig, add_pooling_layer=False)

# %%
longformer
# Out:
# LongformerModel(
#   (embeddings): LongformerEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=1)
#     (position_embeddings): Embedding(512, 768, padding_idx=1)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): LongformerEncoder(
#     (layer): ModuleList(
#       (0): LongformerLayer(
#         (attention): LongformerAttention(
#           (self): LongformerSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (query_global): Linear(in_features=768, out_features=768, bias=True)
#             (key_global): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
longformerconfig
